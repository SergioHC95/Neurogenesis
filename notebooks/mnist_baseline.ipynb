# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys

os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
print(project_root)
# Out:
# c:\Users\sergi\Dropbox\Sergio HC\GitHub\Neurogenesis

# %%
from experiments.mnist_baseline import run_experiment

run_experiment()
# Out:
# Epoch 12/20 | Train loss: 0.0134, Val loss: 0.1165, Val acc: 97.65%
# Epoch 13 [Train]:   0%|          | 0/422 [00:00<?, ?batch/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 from experiments.mnist_baseline import run_experiment
# ----> 3 run_experiment()
#
# File c:\Users\sergi\Dropbox\Sergio HC\GitHub\Neurogenesis\experiments\mnist_baseline.py:118, in run_experiment(cfg, exp_prefix)
#     101 plot_path = f"./results/plots/{expname}_curve.png"
#     103 trainer = NotebookFullFeaturedTrainer(
#     104     model,
#     105     optimizer,
#    (...)    115     resume_if_exists=False,
#     116 )
# --> 118 trainer.train(epochs=cfg.epochs, print_every=1, validate_every=1, plot=True)
#     119 trainer.plot_learning_curve(save=True, path=plot_path)
#     120 test_acc = trainer.evaluate(test_loader)
#
# ...

# %%
from experiments.mnist_baseline import Config, run_experiment

cfg = Config(wd=1e-4)
run_experiment(cfg, exp_prefix="AdamW1e-4")
# Out:
# Final Test Accuracy: 91.67%

# %%
from experiments.mnist_baseline import Config, run_experiment

cfg = Config(wd=1e-3)
run_experiment(cfg, exp_prefix="AdamW1e-3")
# Out:
# Final Test Accuracy: 91.67%

# %%
from experiments.mnist_baseline import Config, run_experiment

cfg = Config(wd=1e-2)
run_experiment(cfg, exp_prefix="AdamW1e-2")
# Out:
# Final Test Accuracy: 91.67%

# %%
from experiments.mnist_baseline import Config, run_experiment

cfg = Config(epochs=40, batch_size=256, wd=1e-3, run_types=("minibatch",))
run_experiment(cfg, exp_prefix="AdamW1e-3_256")

cfg = Config(epochs=100, batch_size=256, wd=1e-3, run_types=("batch",))
run_experiment(cfg, exp_prefix="AdamW1e-3_256")
# Out:
# Final Test Accuracy: 97.23%

# %%
from experiments.mnist_baseline import Config, run_experiment

cfg = Config(epochs=1000, wd=1e-4, run_types=("batch",))
run_experiment(cfg, exp_prefix="AdamW1e-4")

cfg = Config(epochs=1000, wd=1e-3, run_types=("batch",))
run_experiment(cfg, exp_prefix="AdamW1e-3")

cfg = Config(epochs=1000, wd=1e-2, run_types=("batch",))
run_experiment(cfg, exp_prefix="AdamW1e-2")

cfg = Config(epochs=1000, wd=1e-1, run_types=("batch",))
run_experiment(cfg, exp_prefix="AdamW1e-1")

cfg = Config(epochs=1000, wd=1e-1, run_types=("batch",))
run_experiment(cfg, exp_prefix="AdamW1e-1")
# Out:
# Epoch 384/1000 | Train loss: 0.0015, Val loss: 0.0926, Val acc: 97.92%
# Epoch 385 [Train]:   0%|          | 0/1 [00:00<?, ?batch/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 4
#       1 from experiments.mnist_baseline import Config, run_experiment
#       3 cfg = Config(epochs=1000, wd=1e-4, run_types=("batch",))
# ----> 4 run_experiment(cfg, exp_prefix="AdamW1e-4")
#       6 cfg = Config(epochs=1000, wd=1e-3, run_types=("batch",))
#       7 run_experiment(cfg, exp_prefix="AdamW1e-3")
#
# File c:\Users\sergi\Dropbox\Sergio HC\GitHub\Neurogenesis\experiments\mnist_baseline.py:114, in run_experiment(cfg, exp_prefix)
#     100 checkpoint_path = f"./results/checkpoints/{expname}.pt"
#     101 plot_path = f"./results/plots/{expname}_curve.png"
#     103 trainer = NotebookFullFeaturedTrainer(
#     104     model,
#     105     optimizer,
# ...
